# %% [markdown]
# <img width="200" style="float:left"
#      src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Apache_Spark_logo.svg" />

# %% [markdown]
# <img width="500" style="float:center"
#      src="https://images6.alphacoders.com/119/1191374.jpg" />

# %% [markdown]
# # GraphFrames
# * [Business Case](#0)
# * [1. Setup](#1)
#   * [1.1 Start Hadoop](#1.1)
#   * [1.2 Spark Installation](#1.2)
#   * [1.3 Create SparkSession](#1.3)
# * [2. Twitter & SquidGame](#2)
#   * [2.1 Import the data into a Spark DataFrame ](#2.1)
#   * [2.2 Data processing](#2.2)
#   * [2.3 Create the nodes & edges DataFrame](#2.3)
#   * [2.4 Create the GraphFrame](#2.4)
# * [3. Analytics](#3)
#   * [3.1. Conversation: Which are the top 10 most common account pairs in the SquidGame conversation?](#3.1)
#   * [3.2. Conversation: Which are the top 10 accounts with more triangles in the SquidGame conversation?](#3.2)
#   * [3.3. Conversation: How many communities/clusters are in the SquidGame conversation?](#3.3)
#   * [3.4. Conversation: Which are the top 5 most important accounts in the SquidGame conversation?](#3.4)
#   * [3.5. Conversation: Which are the top 5 accounts that mentioned other accounts the most in the SquidGame conversation?](#3.5)
#   * [3.6. Conversation: Which are the top 5 accounts that were mentioned the most in the SquidGame conversation?](#3.6)
# * [4. Export graph data](#4)
# * [5. Finalize the exercise](#5)
#   * [5.1 Stop the Hadoop service](#5.1)

# %% [markdown]
# <a id='0'></a>
# ## Business Case
#
# <p>To further understand user's behavior and find valuable insights for the future marketing campaign of the second season of Squid Game, Netflix has asked Team H, as analytics consultants, to set up advanced analysis of a batch dataset containing 80K tweets to provide insights on the relationship between accounts and the mentions associated to those accounts. Hence, to find valuable information regarding the batch dataset, Team H has established 6 key business questions aligned with the Marketing and Sales strategy following two different pillars: who are the users? Which is their relationship?. Therefore, this Jupyter Notebook is a compilation of ready-to-query consumer-insights questions that aims to support those strategic teams with insights into the Squid Game conversations.
#
# </div>
#
# <ul class="roman">
#      <li> Quick insights on the general conversation relationships </li>
#      <ul class="square">
#  <li>1. Conversation: Which are the top 10 most common account pairs in the SquidGame conversation?</li>
#  <li>2. Conversation: Which are the top 10 accounts with more triangles in the SquidGame conversation?</li>
#  <li>3. Conversation: How many communities/clusters are in the SquidGame conversation?
#  </ul>
#  <li> Quick insights on the individual conversation:
#  <ul class="square">
#  <li>4. Conversation Background: Which are the top 5 most important accounts in the SquidGame conversation?</li>
#  <li>5. Conversation Background: Which are the top 5 accounts that mentioned other accounts the most in the SquidGame conversation?</li>
#  <li>6. Conversation Background: Which are the top 5 accounts that were mentioned the most in the SquidGame conversation?</li>

# %% [markdown]
# <a id='1'></a>
# ## 1. Setup
#
# Since we are going to process data stored from HDFS let's start the service

# %% [markdown]
# <a id='1.1'></a>
# ### 1.1 Start Hadoop
# <p>Dear Marketing Team, before starting to use this notebook please be sure that you log into the course environment by:</p>
# <ul>
#     <li><p><b>Start the Hadoop service</b>:
#         <br/><em>\$ hadoop-start.sh</p></em><br/></li>

# %% [markdown]
# <a id='1.1'></a>
# ### 1.1 Spark Installation
# <p>This step is required for working with the data.

# %%
import findspark
findspark.init()

# %% [markdown]
# <p> We change pandas DataFrame max column width and row to improve data displaying.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <a id='1.2'></a>
# ### 1.2 Create the SparkSession
# <p>By setting this environment variable we can include extra libraries in our Spark cluster. We will add GraphFrames since this library is not in spark core.

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages "graphframes:graphframes:0.8.2-spark3.2-s_2.12" --jars /opt/hive3/lib/hive-hcatalog-core-3.1.2.jar pyspark-shell'

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import *
import random

# %% [markdown]
# <a id='1.3'></a>
# ### 1.3 SparkSession
# <p>By setting this environment variable we can include extra libraries in our Spark cluster.<br/>

# %%
spark = (SparkSession.builder
    .appName("Squid Game - Group G")
    .config("spark.sql.warehouse.dir","hdfs://localhost:9000/datalake")
    .config("spark.sql.legacy.timeParserPolicy","LEGACY")
    .enableHiveSupport()
    .getOrCreate())
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark3/jars/spark-unsafe_2.12-3.0.3.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Ivy Default Cache set to: /home/osbdet/.ivy2/cache
# The jars for the packages stored in: /home/osbdet/.ivy2/jars
# :: loading settings :: url = jar:file:/opt/spark3/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# graphframes#graphframes added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-10b22930-6f14-45eb-b1fb-4a55ed78f3a0;1.0
# 	confs: [default]
# 	found graphframes#graphframes;0.8.2-spark3.2-s_2.12 in spark-packages
# 	found org.slf4j#slf4j-api;1.7.16 in central
# :: resolution report :: resolve 409ms :: artifacts dl 8ms
# 	:: modules in use:
# 	graphframes#graphframes;0.8.2-spark3.2-s_2.12 from spark-packages in [default]
# 	org.slf4j#slf4j-api;1.7.16 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   2   |   0   |   0   |   0   ||   2   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-10b22930-6f14-45eb-b1fb-4a55ed78f3a0
# 	confs: [default]
# 	0 artifacts copied, 2 already retrieved (0kB/5ms)
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
from pyspark.sql.types import *
batch_customschema = StructType([
StructField(
 "name", StringType(), True),StructField(
 "location", StringType(), True),StructField(
 "description", StringType(), True),StructField(
 "twitter_created_at", StringType(), True),StructField(
 "followers_count", LongType(), True),StructField(
 "friends_count", LongType(), True),StructField(
 "favourites_count", LongType(), True),StructField(
 "verified", BooleanType(), True),StructField(
 "created_at", StringType(), True),StructField(
 "text", StringType(), True),StructField(
 "source", StringType(), True),StructField(
 "retweeted", BooleanType(), True)])

# %% [markdown]
# <a id='2'></a>
# ## 2. Twitter & SquidGame
# Here we will extract and clean the necessary pieces of data within our dataset and which is going to be used in the 'Analytics" step

# %% [markdown]
# <a id='2.1'></a>
# ### 2.1 Import the data into a Spark DataFrame

# %%
# We import the Squid Game conversation from twitter into a spark DataFrame ('squidgameDF').
squidgameDF = spark.read.format("csv").options(header="true", multiline="true")\
    .schema(batch_customschema).load("hdfs://localhost:9000/datalake/raw")

# %% [markdown]
# <a id='2.2'></a>
# ### 2.2 Exploratory data analysis

# %% [markdown]
# #### 1. Who are the users? Verified distinct accounts that talked about SquidGame with highest following:

# %%
most_followed_df = (squidgameDF
          .groupBy("name")
          .agg(max("followers_count").alias("followers_count"))
          .orderBy(desc("followers_count"))
          .limit(5))
most_followed_df.toPandas()

# They ended up being the same as the verified!
# Out:
#              name  followers_count
# 0            9GAG         16846417
# 1  Vogue Magazine         14359408
# 2       billboard         12588047
# 3         E! News         11710347
# 4      Twitter TV          9207638

# %% [markdown]
# #### 2. Who are the users? Ratio of Verified accounts in the conversation of SquidGame:

# %%
verified_ratio_df = squidgameDF.groupBy("verified").agg(count("*").alias("Count")).sort(col("Count").desc())

verified_ratio_df.toPandas()

# 4% of the users tweeting about SquidGame have verified accounts
# 95% have unverified accounts
# Out:
#   verified  Count
# 0    False  76411
# 1     True   3292
# 2     None   1981

# %% [markdown]
# #### 3. Who are the users? Popularity of Twitter users on the Top 10 locations:

# %%
import pyspark.sql.functions as f

# %%
size_summary = squidgameDF.groupBy("verified")\
        .agg(
            f.count("*").alias("Count"),
            f.max("followers_count").alias("Max_Followers_Count"),
            f.round(f.avg("followers_count")).alias("Avg_followers_count"),
            f.min("followers_count").alias("Min_Followers_Count"))\
        .sort(f.col("Count").desc())\
        .show(10)

size_summary

# Here we can see that one of the verified accounts actually has only 14 followers, showing that being verified does not mean large following.
# Out:
# [Stage 8:==================================================>    (183 + 3) / 200]
# +--------+-----+-------------------+-------------------+-------------------+
# |verified|Count|Max_Followers_Count|Avg_followers_count|Min_Followers_Count|
# +--------+-----+-------------------+-------------------+-------------------+
# |   false|76411|             944282|             2226.0|                  0|
# |    true| 3292|           16846417|           383938.0|                 14|
# |    null| 1981|              52912|             8494.0|                  1|
# +--------+-----+-------------------+-------------------+-------------------+

# %% [markdown]
# #### 4. Who are the users? Top 5 common users with more tweets published about SquidGame:

# %%
top_users_df = (squidgameDF.groupBy("name")
          .agg(count("*").alias("Count"))
          .orderBy(desc("Count"))
          .limit(5))
top_users_df.toPandas()
# Out:
#           name  Count
# 0   Sale X Low    395
# 1    John Doge    263
# 2       7-Ainu    170
# 3    Ofofonobs    140
# 4  havingalaff    110

# %% [markdown]
# <a id='2.3'></a>
# ### 2.3. Data processing

# %%
# We create a pandas DataFrame ('squidDF') for processing.
squidDF = squidgameDF.toPandas()

# %%
# We obtain an insight on how many tweets we are going to process in our analysys.
squidDF['text'].count()
# Out:
# 80905

# %%
# We extract the mentions(@) and we add them to a new column named 'mentions'.
squidDF['mentions'] = squidDF['text'].str.findall(r'[＠@]([^][\s#<>|{}]+)')

# We use the function .explode() to unstack the obtained list of mentions into a row containing only one mention. 
squidDF = squidDF.explode('mentions')

# We drop all the tweets with no mentions in our pandas DataFrame. 
squidDF = squidDF.dropna()

# %%
# We obtain a high-level oeverview of the information we have.
squidDF.head(5)
# Out:
#           name        location  \
# 5   Peyman 🅚🅐🅘  United Kingdom
# 14      Yemzxy  Lagos, Nigeria
# 26   EarlyGame         Germany
# 31     Charlie  United Kingdom
# 31     Charlie  United Kingdom
#
#                                                                                                                                                            description  \
# 5                                             Official @KardiaChain $KAI Ambassador\nMarketing Advisor @kephigallery\nGraphics and Film Artist https://t.co/OsTOSEKrHt
# 14                                                                                                                                     Am special because am a triplet
# 26                                                                                                                                                       Own Your Game
# 31  Aspiring Youtuber/Content creator.\nDisclaimer: Charlogical is a Brand\nThe content posted is reviewed and published by the Charlogical Team\nTeam@charlogical.com
# 31  Aspiring Youtuber/Content creator.\nDisclaimer: Charlogical is a Brand\nThe content posted is reviewed and published by the Charlogical Team\nTeam@charlogical.com
#
#            twitter_created_at  followers_count  friends_count  \
# 5   2018-01-27 12:07:31+00:00            546.0          318.0
# 14  2021-06-11 16:47:29+00:00             39.0          160.0
# 26  2019-11-13 14:56:55+00:00          49381.0          153.0
# 31  2020-02-07 22:43:29+00:00             24.0           47.0
# 31  2020-02-07 22:43:29+00:00             24.0           47.0
#
#     favourites_count verified                 created_at  \
# 5             6265.0    False  2021-10-06 12:04:54+00:00
# 14              12.0    False  2021-10-06 12:02:57+00:00
# 26             963.0    False  2021-10-06 12:01:25+00:00
# 31             463.0    False  2021-10-06 12:00:26+00:00
# 31             463.0    False  2021-10-06 12:00:26+00:00
#
#                                                                                                                                                text  \
# 5    $THG\nGoing to explode to 4B Marketcap very soon.\nThe world first MOBA\nThis game is on another level!\n@KardiaChain… https://t.co/4Y2bO088JM
# 14  The saga continues \nGet data cheap  @honourworldng \nMessage us on https://t.co/0ehyV9EP4w\n#twitch #SquidGame #2baba… https://t.co/ASDjPpp2EH
# 26                                                                                             Season 2? 😂 @Xbox #SquidGame https://t.co/OoAAie9EaW
# 31    I Didn't mean to push her off - Squid Game Roblox https://t.co/J6olOsZMj5 @youtube @YouTubeGaming @roblox\n\n#roblox… https://t.co/oE9P1UU2iE
# 31    I Didn't mean to push her off - Squid Game Roblox https://t.co/J6olOsZMj5 @youtube @YouTubeGaming @roblox\n\n#roblox… https://t.co/oE9P1UU2iE
#
#                  source retweeted       mentions
# 5   Twitter for Android     False   KardiaChain…
# 14  Twitter for Android     False  honourworldng
# 26        PromoRepublic     False           Xbox
# 31      Twitter Web App     False        youtube
# 31      Twitter Web App     False  YouTubeGaming

# %%
# We create a new pandas DataFrame ('squidTweets') with only the variables we need for our analysis. 
squidTweets = squidDF[['name','mentions']]

# %%
# We convert our pandas DataFrame ('squidTweets') into a spark DataFrame ('SquidGameTweets'), so we are now able to process this information with GraphFrames.
SquidGameTweets=spark.createDataFrame(squidTweets)
SquidGameTweets.printSchema()
SquidGameTweets.show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- mentions: string (nullable = true)
#
# +--------------------+---------------+
# |                name|       mentions|
# +--------------------+---------------+
# |       Peyman 🅚🅐🅘|   KardiaChain…|
# |              Yemzxy|  honourworldng|
# |           EarlyGame|           Xbox|
# |             Charlie|        youtube|
# |             Charlie|  YouTubeGaming|
# |             Charlie|         roblox|
# |              Finder|      netflix's|
# |       Malcolm Scott|   Kathryn_Fisk|
# |🌊🌊Becca Ashley ...|       hodakotb|
# |             제로 ◡̈| LouisVuitton’s|
# |        DogFarm Coin|    DogFarmCoin|
# |        Nikki Jacobs|      NetflixSA|
# |      Suterusu Daioh| VAMichaelaLaws|
# |      Monbebe Nation|OfficialMonstaX|
# |           Ruben Rbg|  thisisinsider|
# |            Gitartsy|         UNILAD|
# |            Gitartsy|       ladbible|
# |        SarahGen | ☕| millionaireeth|
# |            Gitartsy|         UNILAD|
# |   Valtteri Aaltonen|alessiadelvasto|
# +--------------------+---------------+
# only showing top 20 rows

# %%
# We obtain an insight on how many valid tweets we have left for effective analysis after our data cleaning .
SquidGameTweets.count()
# Out:
# 12560

# %% [markdown]
# <a id='2.4'></a>
# ### 2.4 Create the nodes & edges DataFrame
#
# This step is important since it will allow us to crete the variables 'vertices' and 'edges' which are indispensable inputs needed for GraphFrame to be able to process and extact meaningful insights and identifying relationships in the data.

# %%
# We create the vertices/nodes.
tweets_vertices = (SquidGameTweets.select("name").distinct().withColumnRenamed("name","id"))
print(tweets_vertices.count())

# We create the edges.
tweets_edges = (SquidGameTweets.withColumnRenamed("name","src").withColumnRenamed("mentions","dst").groupBy("src","dst").agg(count("*").alias("occurrences")))
print(tweets_edges.count())
# Out:
# 6072
# [Stage 19:===================================================>  (191 + 4) / 200]
# 10045

# %% [markdown]
# <a id='2.5'></a>
# ### 2.5 Create the GraphFrame

# %%
# We import GraphFrame
from graphframes import GraphFrame

# We create the graphframe framework needed for answering our questions about the SquidGame conversation.
tweets_graph = GraphFrame(tweets_vertices, tweets_edges)
tweets_graph.cache()
# Out:
# GraphFrame(v:[id: string], e:[src: string, dst: string ... 1 more field])

# %% [markdown]
# <a id='3'></a>
# # 3. Analytics
#
# In this notebook, we will be answering 6 essential business questions for both the marketing and sales team to better understand the conversation of SquidGame on Twitter.

# %% [markdown]
# <a id='3.1'></a>
# **1. Conversation: Which are the top 10 most common account pairs in the SquidGame conversation?**

# %%
tweets_graph.edges.orderBy(desc("occurrences")).limit(10).toPandas()
# Out:
#           src            dst  occurrences
# 0  marziolowe        opensea           82
# 1  Sale X Low      katyperry           61
# 2  Sale X Low      cristiano           49
# 3  Sale X Low        rihanna           47
# 4  Sale X Low   ArianaGrande           47
# 5  Sale X Low    barackobama           45
# 6     MLN PXL       withFND!           41
# 7  Sale X Low   TheEllenShow           40
# 8  Sale X Low  taylorswift13           37
# 9  Sale X Low   justinbieber           35

# %% [markdown]
# <a id='3.2'></a>
# **2. Conversation: Which are the top 10 accounts with more triangles in the SquidGame conversation?**

# %%
tweets_graph.triangleCount().orderBy(desc("count")).limit(10).toPandas()
# Out:
#    count                              id
# 0      0                  #EnjoyDigitAll
# 1      0          (((#RealJewNews+)))💉☠️
# 2      0                      @itinerant
# 3      0                     Alt-TL Hank
# 4      0                    Bayzoo Bawra
# 5      0                  Best Vision TV
# 6      0         Bhadmus Teniola Mubarak
# 7      0               CrossingAfterDark
# 8      0  Deep State Gypsy Skittle Party
# 9      0                   Dubai Tourism

# %% [markdown]
# <a id='3.3'></a>
# **3. Conversation: How many communities/clusters are in the SquidGame conversation?**

# %%
(tweets_graph.stronglyConnectedComponents(maxIter=10)
     .sort("component")
     .groupby("component")
     .agg(collect_list("id").alias("accounts"))).toPandas()
# Out:
#           component                                                accounts
# 0                 0    [AdaletPlatformu #TürkiyeAileMeclisi @iYiLiK.org.TR]
# 1                 1                                         [Adam Williams]
# 2                 2                                            [Arfath Dar]
# 3                 3                                               [Ayeshay]
# 4                 4                                          [Belinda Zhou]
# 5                 5                [Chandler Poling is ready for Halloween]
# 6                 6                                     [CryptoFamousOrign]
# 7                 7                                         [Deanna Kotrla]
# 8                 8                             [Fin, the Other Fangbearer]
# 9                 9                                          [Gary Buglass]
# 10               10                                             [GetAppFox]
# 11               11                      [Hollywood Network 🐱‍🚀 #hollywood]
# 12               12                                           [Jill Trave☈]
# 13               13                                             [John Doge]
# 14               14                                            [Jose Llana]
# 15               15                                                     [K]
# 16               16                                          [Keira Doogue]
# 17               17                                                  [Myol]
# 18               18                                    [News Talk 830 WCCO]
# 19               19                                   [Oliver Jay Michaels]
# 20               20                                     [Queen of Plaistow]
# 21               21                                         [Rachel Burden]
# 22               22                                                [SANT2💧]
# 23               23                                              [StarSeed]
# 24               24                                   [Translate By Humans]
# 25               25                                         [TreBionPrince]
# 26               26                                   [Troll Cinema ( TC )]
# 27               27                                               [Truongy]
# 28               28                                           [humanenergy]
# 29               29                                                 [𓆩 ★ 𓆪]
# 30               30                                          [𝙎𝙖𝙪𝙧𝙖𝙫 𝙆𝙪𝙢𝙖𝙧]
# 31               31                    [💀 Jed22EXE 🎃 (IT'S A SPOOKY MONTH)]
# 32       8589934592                                        [#EnjoyDigitAll]
# 33       8589934593                                [(((#RealJewNews+)))💉☠️]
# 34       8589934594                                            [@itinerant]
# 35       8589934595                                           [Alt-TL Hank]
# 36       8589934596                                          [Bayzoo Bawra]
# 37       8589934597                                        [Best Vision TV]
# 38       8589934598                               [Bhadmus Teniola Mubarak]
# 39       8589934599                                     [CrossingAfterDark]
# 40       8589934600                        [Deep State Gypsy Skittle Party]
# 41       8589934601                                         [Dubai Tourism]
# 42       8589934602                                                 [Ginny]
# 43       8589934603                                          [Iamwillysart]
# 44       8589934604                   [JST☆R _ 제시카 Roydo/IMFACT/FROM20/TFC]
# 45       8589934605                                          [Jason Magnum]
# 46       8589934606                                          [Kevin Asbell]
# 47       8589934607                                         [Khalid Hanief]
# 48       8589934608                                                [Livie✌]
# 49       8589934609                                         [Morgan Murphy]
# 50       8589934610                                        [Neil Roc Bilon]
# 51       8589934611                                             [PokerNews]
# 52       8589934612                                           [Red Raccoon]
# 53       8589934613                                         [The Late Show]
# 54       8589934614                                           [Troy Salmon]
# 55       8589934615                                       [Urstruly_Suraj🔔]
# 56       8589934616                                        [danielle paige]
# 57      17179869184                                                   [666]
# 58      17179869185                                        [Atharva Kalele]
# 59      17179869186                                      [Atmosphere.Radio]
# 60      17179869187                                                   [Avi]
# 61      17179869188                                         [DGA Disc Golf]
# 62      17179869189                                                [Damien]
# 63      17179869190                                            [Hafiz Aziz]
# 64      17179869191                                          [Kendyl Neus✨]
# 65      17179869192                                        [Liam Farnworth]
# 66      17179869193                                      [Myranda Johnston]
# 67      17179869194                                         [Raymond J Lee]
# 68      17179869195                          [Sei ⧖∞🥂🏳️‍🌈 ATEEZ MONTH🎃🏴‍☠️]
# 69      17179869196                                          [Sophie Jeong]
# 70      17179869197                                           [Steve Boese]
# 71      17179869198                                      [The Good Child💁🏽]
# 72      17179869199                                         [Tobias Pütter]
# 73      17179869200                                                  [Trev]
# 74      17179869201                                      [Zach Glasbrenner]
# 75      17179869202                                     [ecemdilankose.eth]
# 76      17179869203                                         [rasikaforreal]
# 77      17179869204                                                   [정호연]
# 78      17179869205                              [🍀|EMOT GENI KARO MELET|🍀]
# 79      25769803776                                           [Ana Quinata]
# 80      25769803777                                        [Anthony Borges]
# 81      25769803778                                              [BlakJak:]
# 82      25769803779                                         [Blake Currall]
# 83      25769803780                                             [Broadcast]
# 84      25769803781                                             [Chas Holl]
# 85      25769803782                                          [DNCTV MEDIA®]
# 86      25769803783                                                 [Goose]
# 87      25769803784                                               [Irena 🐝]
# 88      25769803785                                       [Jaina Lee Ortiz]
# 89      25769803786                                            [KaBrookNFT]
# 90      25769803787                                       [Mahsa Zolfkhani]
# 91      25769803788                                       [Michael Kennedy]
# 92      25769803789                                        [Mono Loco 🏴‍☠️]
# 93      25769803790                                           [Nick Sharma]
# 94      25769803791                                            [Noorhan_sj]
# 95      25769803792                                                    [PC]
# 96      25769803793                                             [Pome Pete]
# 97      25769803794                                                 [Scott]
# 98      25769803795                                                [Squarp]
# 99      25769803796                                        [Travis Ellison]
# 100     25769803797                                              [collᎥe 🗯]
# 101     25769803798                                       [makeflycheap.in]
# 102     25769803799                                           [mohammad563]
# 103     25769803800                                            [mySumatera]
# 104     25769803801                                       [veronica Briggs]
# 105     25769803802                                            [விக்னேஷ் 💙]
# 106     25769803803                             [𝐀𝐑𝐓𝐒𝐁𝟏𝟗 𝐒𝐭𝐞𝐥𝐥𝐢𝐜𝐢𝐨𝐮𝐬⁷👽(IA)]
# 107     34359738368                                                   [718]
# 108     34359738369                                  [Akwelz 🇨🇵 akwelz.tez]
# 109     34359738370     [Cashanova Clutch Hustle - #BillsMafiaFamilyHammer]
# 110     34359738371                                                [DevOla]
# 111     34359738372                                          [Georgia Coan]
# 112     34359738373                                              [Henrique]
# 113     34359738374                                        [I love animals]
# 114     34359738375                                  [International Breeze]
# 115     34359738376                                      [Jack Blank Space]
# 116     34359738377                                          [Jazz Johnson]
# 117     34359738378                                                 [Lou 💫]
# 118     34359738379                                     [Mashable Pakistan]
# 119     34359738380                                     [Md.Monjurul Islam]
# 120     34359738381                                          [Meganthemess]
# 121     34359738382                                        [Mira Abegail 🍥]
# 122     34359738383                                        [News Source LA]
# 123     34359738384                                        [PAUL MCDERMOTT]
# 124     34359738385                                          [Simon Jacobs]
# 125     34359738386                                        [Stuart St.John]
# 126     34359738387                                          [Tech Scaling]
# 127     34359738388                                    [Time Out Abu Dhabi]
# 128     34359738389                                            [Wanderer..]
# 129     34359738390                                     [YourFavIgboQueen👸]
# 130     34359738391                                            [Yumango_YT]
# 131     34359738392                                            [ZandlSlant]
# 132     34359738393                                 [artkuroneko (´-ω-`) ⁷]
# 133     34359738394                                            [jass_rosie]
# 134     34359738395                                                  [juls]
# 135     34359738396                                               [onecvj🐺]
# 136     34359738397                                                [ronnnn]
# 137     42949672960                                          [CRYPTOBUNNYS]
# 138     42949672961                        [Caroline Fan 范愷苓 #StopAAPIHate]
# 139     42949672962                                         [Crypto Hawk 💎]
# 140     42949672963                                        [Diana Restrepo]
# 141     42949672964                                           [Ella Walker]
# 142     42949672965                                           [Emma Clarke]
# 143     42949672966                                    [England Is Burning]
# 144     42949672967                                           [GeorgeSUGAR]
# 145     42949672968             [Jelo G. Candy-tos | 👻💀⚰️🎃🧛🏻‍♂️ | 🔶🔴⚫️⚪️🟡🔶]
# 146     42949672969                                                  [Jina]
# 147     42949672970                                     [Ka From The South]
# 148     42949672971                                           [Kuldeep Roy]
# 149     42949672972                                     [Lauren MacDougall]
# 150     42949672973         [Lord Bernfredo - Race Human #WeLoveGinaCarano]
# 151     42949672974                                           [Mar Almeida]
# 152     42949672975                                         [Michael Bates]
# 153     42949672976                                        [MindSet Gaming]
# 154     42949672977                                          [Misael Duran]
# 155     42949672978                                [Peachy°🍑 6️⃣5️⃣🎹 LIMIT]
# 156     42949672979                               [Ron Deets For US Senate]
# 157     42949672980                                                [Teelip]
# 158     42949672981                                  [The Correspondent PK]
# 159     42949672982                                         [UNILORIN VC🎣🎏]
# 160     42949672983                                           [VIXX_240512]
# 161     42949672984                                               [gonzoDP]
# 162     42949672985                                  [shanaka bakmeedeniya]
# 163     42949672986                                                [~NadD~]
# 164     42949672987                                       [🎤⚡️🦞JJ Hayes 🎧🎙]
# 165     42949672988                              [🐻 Nambi The Happy Bear 🐻]
# 166     51539607552                                                    [1A]
# 167     51539607553                                  [BTS DANISH ARMY ⁷ 🇩🇰]
# 168     51539607554                                             [Ben Chung]
# 169     51539607555                [Caleb and Joshua the Warriors.🌸✨💫🌾🥋🎄🐑🦌]
# 170     51539607556                                              [Claudia.]
# 171     51539607557                                          [Dick Satanas]
# 172     51539607558                                               [E! News]
# 173     51539607559                                   [Ellie @ Gamestarter]
# 174     51539607560                                              [Genspace]
# 175     51539607561                                          [Gohel Pratik]
# 176     51539607562                                           [JANARTHANAN]
# 177     51539607563                                      [Jeannie Kelly 💙💛]
# 178     51539607564                                             [KingNisch]
# 179     51539607565    [Mache- that guy who does the artwork on the shoes.]
# 180     51539607566                         [PAYC - Monthly NFT membership]
# 181     51539607567            [Second Cousin Of Robert Rinder MBE* 🇮🇱🇮🇱🇮🇱]
# 182     51539607568                                              [Shanaroo]
# 183     51539607569                                              [Shihad K]
# 184     51539607570                                         [Squid game 🦍💨]
# 185     51539607571                                            [SuperJude™]
# 186     51539607572                                             [VBET News]
# 187     51539607573                                           [Will Wilson]
# 188     51539607574                                              [andz.eth]
# 189     51539607575                                           [student.eth]
# 190     51539607576                                        [teguhpramudani]
# 191     51539607577                                                  [vivi]
# 192     51539607578                                              [𝕯𝖔𝖓𝖆𝖑𝖉 🎃]
# 193     60129542144                                                 [Bulls]
# 194     60129542145                                              [Danoskie]
# 195     60129542146                                                [Elliot]
# 196     60129542147                                       [Fandom Spotlite]
# 197     60129542148                                           [HE Creative]
# 198     60129542149                                          [INCOGNITO 🇺🇬]
# 199     60129542150                                           [Jacob Beard]
# 200     60129542151                                            [Jane Rosse]
# 201     60129542152                                       [Kev McKevinface]
# 202     60129542153                                              [Krason22]
# 203     60129542154                                [Lacey Deets 👻🐇laceyboi]
# 204     60129542155                                       [Louisa Houghton]
# 205     60129542156                                                   [M.O]
# 206     60129542157                                             [MOMENTOUS]
# 207     60129542158                                      [Md.Talim Hossain]
# 208     60129542159                                   [Mücahit Büyükyılmaz]
# 209     60129542160                                           [Nick Roseth]
# 210     60129542161                                [PALSE by Paledi Segapo]
# 211     60129542162                            [Rich Greenfield, LightShed]
# 212     60129542163                                        [SANA💜||SEULGI💛]
# 213     60129542164                                        [Sam Richardson]
# 214     60129542165                                                 [Steve]
# 215     60129542166                                                  [T🎃B👻]
# 216     60129542167                                     [Yurii Bitcoinov 🎏]
# 217     60129542168                                                [sachyn]
# 218     60129542169                                               [सूरज 🇮🇳]
# 219     60129542170                                       [이정재 LEE JUNGJAE]
# 220     60129542171                                         [𝑪𝒉𝒖𝒖𝒌𝒐𝒓𝒓𝒐 ⁷ 🌺]
# 221     60129542172                                         [𝙍𝘼𝙅𝙀𝙎𝙃 𝙋𝘼𝙍𝙄𝙆𝙃]
# 222     60129542173                                     [🌺yunho's dhadkan🌺]
# 223     68719476736                                [*I'm a sucker for tae*]
# 224     68719476737                                               [ARNiE81]
# 225     68719476738                                                [AnLisa]
# 226     68719476739                                                [AndréV]
# 227     68719476740                                      [Ashraful Arif 🇧🇩]
# 228     68719476741                                                  [BIBU]
# 229     68719476742                  [Bodoque_(LEAKED) - #HackerChilean 🇨🇱]
# 230     68719476743                                          [C4 Gogglebox]
# 231     68719476744                     [Caleb Fumnaya (AsabaPropertyPlug)]
# 232     68719476745                                     [Certified Savage😈]
# 233     68719476746                                           [Dad William]
# 234     68719476747                                        [Danny Hayasaka]
# 235     68719476748                                                  [Espy]
# 236     68719476749                                   [Heart Hertfordshire]
# 237     68719476750                                              [Honer 🎙️]
# 238     68719476751                                        [Hungry Highway]
# 239     68719476752                                                   [J T]
# 240     68719476753                                  [JFlores luvs crypto!]
# 241     68719476754                                        [Jacques Frisch]
# 242     68719476755                                         [Jenese Harris]
# 243     68719476756                                                  [Josh]
# 244     68719476757                                            [K.Babiee 💋]
# 245     68719476758                                          [LL Cool Jode]
# 246     68719476759                                   [Liam the Leprechaun]
# 247     68719476760                                           [Loan Pronto]
# 248     68719476761                                         [Logo Designer]
# 249     68719476762                                           [MIKATENSITY]
# 250     68719476763                                        [PennyDreadfull]
# 251     68719476764                                  [PsychoboyUK (Ronnie)]
# 252     68719476765                                   [Richard Tamez Umali]
# 253     68719476766                                                   [Ryu]
# 254     68719476767                               [Tanya Graham, DVM (ret)]
# 255     68719476768                                                [sirens]
# 256     68719476769                                                   [김루인]
# 257     68719476770                                       [ｱ尺ﾑ丂ﾑり 乃んひズ乇乃ﾑム]
# 258     77309411328             [#BernieSanders #MedicareForAll #WearAMask]
# 259     77309411329                                              [AJ-TOONZ]
# 260     77309411330                                                [Amanda]
# 261     77309411331                                        [April M 2️⃣3️⃣]
# 262     77309411332                                          [Becky Moss 💙]
# 263     77309411333                                       [Eveline Ruehlin]
# 264     77309411334                     [Hella_ATEE_Zn 🏴‍☠️ ATZpopper 🏴‍☠️]
# 265     77309411335                                      [Jeeps & Jacuzzis]
# 266     77309411336                                     [Jomari Peterson 🔺]
# 267     77309411337                               [Kalkine Media Australia]
# 268     77309411338                                             [Kronoss Ω]
# 269     77309411339                                    [Lyra Hale 🏳️‍🌈✍️🇵🇷]
# 270     77309411340                                          [Marlon Allen]
# 271     77309411341                            [Medical Macaroni | دوالےلو]
# 272     77309411342                [Ms Defiant #FBPA #FBPE #FBPPR #FBNHS 🕷]
# 273     77309411343                     [My Profile Picture is 1000 Words.]
# 274     77309411344                            [NFT | BUILDING COMMUNITIES]
# 275     77309411345                                 [Nilley #LabanLeni2022]
# 276     77309411346                                        [Orlando Garner]
# 277     77309411347                          [Paul Little, vacc'd & masked]
# 278     77309411348                                             [Pennywise]
# 279     77309411349                                      [TRON Community 🅣]
# 280     77309411350                                        [This Side Op 📦]
# 281     77309411351                                           [World Punkz]
# 282     77309411352                                    [Your Favorite Girl]
# 283     77309411353                                   [intotheMichaelverse]
# 284     77309411354                                                [myst 🗯]
# 285     77309411355                                  [☠️🦅 Vampire Crow ☠️🦅]
# 286     85899345920                                      [Aneta /not Anita]
# 287     85899345921                                            [Be Nutral🧩]
# 288     85899345922                                     [David Miller 🏳️‍🌈]
# 289     85899345923                                      [Emmanuel Pacheco]
# 290     85899345924                                           [Eric Berlin]
# 291     85899345925                               [Freocookster ⚓ Easy A.Z]
# 292     85899345926                                            [Grimm_Book]
# 293     85899345927                                        [Jack Szwergold]
# 294     85899345928                                   [Jollof n Chill, LLC]
# 295     85899345929                                        [KELLY MAINELLI]
# 296     85899345930                                                    [K✨]
# 297     85899345931                                      [LlaBron James 🦁👑]
# 298     85899345932                                           [Mike Proulx]
# 299     85899345933                                           [Mooballoono]
# 300     85899345934                                                 [Nadia]
# 301     85899345935                                              [Natdanai]
# 302     85899345936                                          [NoMoreTorPor]
# 303     85899345937                           [SpoopyWolverine #BeASpartan]
# 304     85899345938                                              [Tracy S.]
# 305     85899345939                                       [Tyler Banham 🇨🇦]
# 306     85899345940                                   [Undercranked Agents]
# 307     85899345941                                            [Yvonne Kai]
# 308     85899345942                                             [collᎥe. 👻]
# 309     85899345943                                            [mographity]
# 310     85899345944                                                 [nila3]
# 311     85899345945                                                [partnu]
# 312     85899345946                                         [sahil agarwal]
# 313     85899345947                                             [자신을 사랑하세요]
# 314     85899345948                                            [🇸 🇩 ☞⤀🏔️🕊️]
# 315     85899345949                                   [💫☄️🎃SpookyPenn🎃☄️💫]
# 316     94489280512                                 [*and you’re a killer.]
# 317     94489280513                                           [ACSupremacy]
# 318     94489280514                                         [Aaron Clayton]
# 319     94489280515                                           [Amber LeMay]
# 320     94489280516                                          [Anke Schönle]
# 321     94489280517                                       [Austin Kolodney]
# 322     94489280518                                               [Bi Tran]
# 323     94489280519                                           [Blytheweigh]
# 324     94489280520                                               [Brikesh]
# 325     94489280521              [Caddy Marketing and Communications, Inc.]
# 326     94489280522                                         [Capital Dance]
# 327     94489280523                                           [CityCynic 🐜]
# 328     94489280524                                           [DJTezos.tez]
# 329     94489280525                                       [Dokkaebi™ (도깨비)]
# 330     94489280526                                       [Elias Hernandez]
# 331     94489280527                                         [Eric Thompson]
# 332     94489280528                                        [Erick 🏳️‍🌈🇪🇺🇱🇺]
# 333     94489280529                                          [Ganesh Kumar]
# 334     94489280530                                        [Jennifer Ablan]
# 335     94489280531                                    [MEGAAMOBILEMALL ™️]
# 336     94489280532                                    [Mama Moss 🌺 Vtuber]
# 337     94489280533                                         [Mukesh Kaneri]
# 338     94489280534                                   [Multiversity Comics]
# 339     94489280535                                             [NFL Korea]
# 340     94489280536                                               [Reece 💫]
# 341     94489280537                                                 [Sauce]
# 342     94489280538                                [The Paper Bag Princess]
# 343     94489280539                                                [Wild_C]
# 344     94489280540                                           [Woosang Lee]
# 345     94489280541                                        [madamekatgames]
# 346     94489280542                                  [smokeshop production]
# 347     94489280543                                           [𝔏𝔞 𝔇𝔬𝔠𝔱𝔬𝔯𝔞🐧]
# 348     94489280544                              [🏈🍺Cicero's Surrogate® ☕🚴]
# 349    103079215104                        ["USS THE Chris - ""Hold me."""]
# 350    103079215105                                          [Adnan Rajput]
# 351    103079215106                                         [Alison Brower]
# 352    103079215107                                        [Amale Bouzlafa]
# 353    103079215108                                                 [Chubz]
# 354    103079215109                       [DATA PLUG _ Listen to Magixx EP]
# 355    103079215110                                                [Farzan]
# 356    103079215111                                          [Hi, I’m Jay!]
# 357    103079215112                                           [IamModified]
# 358    103079215113                                     [Insane-sitive guy]
# 359    103079215114                                                 [James]
# 360    103079215115      [Jeff Fowler #ToryScumOut #IStandWithJeremyCorbyn]
# 361    103079215116                                             [Johnnyafc]
# 362    103079215117                                       [Katcef Brothers]
# 363    103079215118                                           [Laxmi Patel]
# 364    103079215119                                      [Michael Scibetta]
# 365    103079215120                                   [NickWroemancer ⭕️🔺🟥]
# 366    103079215121                                           [Only1Sosa ❁]
# 367    103079215122                                          [Rockest Babu]
# 368    103079215123                                           [Romi Moondi]
# 369    103079215124                                           [Tim Carrier]
# 370    103079215125                                    [Yalith Vargas León]
# 371    103079215126                                           [Yankee Rose]
# 372    103079215127                                                [cami ✧]
# 373    103079215128                                                [hombre]
# 374    103079215129                                      [illustratedrosie]
# 375    103079215130                                                  [mey🍒]
# 376    103079215131                                            [ᗩᑎᑎᗩ ᖇIZᕼᗩ]
# 377    103079215132                 [⟬⟭ 𝕃𝔼𝕀𝔸 ⁷ is seeing BTS & Eric Nam ⟭⟬]
# 378    103079215133                              [💢K̷A̷M̷I̷K̷A̷Z̷E̷1̷8̷7̷💢]
# 379    111669149696                                               [8randon]
# 380    111669149697                                             [Aaron Cho]
# 381    111669149698                                              [Alkemint]
# 382    111669149699                                           [ArivuXPress]
# 383    111669149700                               [Beerly Standing Podcast]
# 384    111669149701                                            [Brian Kong]
# 385    111669149702                                 [Chr-AHHHHHHHHH-s Gold]
# 386    111669149703                                     [Dr. Jason Johnson]
# 387    111669149704                                        [Eryck wa Bondo]
# 388    111669149705                                               [Hyaciin]
# 389    111669149706                                           [Iain Martin]
# 390    111669149707                                 [JackBenderProductions]
# 391    111669149708                                               [Jason L]
# 392    111669149709                                        [Kenny Beaumont]
# 393    111669149710                    [Marcus, M.Ed 🤙🏾 6’8” #memorymarcus]
# 394    111669149711                                          [Nate Bullock]
# 395    111669149712                                                [Rhude✨]
# 396    111669149713                                         [Rolf in Kenia]
# 397    111669149714                                           [Saran Kumar]
# 398    111669149715                                          [Saynt Empire]
# 399    111669149716                             [Sri Ram Sai Pavan Relangi]
# 400    111669149717                                      [The Duke’s Spoon]
# 401    111669149718                                      [TheLocationGuide]
# 402    111669149719                                         [Yamini Sharma]
# 403    111669149720                                          [highsnobiety]
# 404    111669149721                                          [midlifebroad]
# 405    111669149722                                   [othersideofthefence]
# 406    111669149723                                           [slanaslana®]
# 407    111669149724                                               [𝕐𝕒𝕖 🍷🤙🏻]
# 408    111669149725                                            [𝗭@𝗗𝗔𝗬𝗬 🐺♈️]
# 409    120259084288                              ["Jon ""Devlishh"" Lloyd"]
# 410    120259084289                                          [Amanda Salas]
# 411    120259084290                                        [Bhadresh Patel]
# 412    120259084291                                           [Chill&Shill]
# 413    120259084292                                  [Christiaan Boonzaier]
# 414    120259084293                                       [DESIGN SHOUTOUT]
# 415    120259084294                                          [Erin Henslee]
# 416    120259084295                                                 [Faria]
# 417    120259084296                                         [GJ #RCB 😷🇮🇳 🔔]
# 418    120259084297                                      [Helen Merryfield]
# 419    120259084298                                          [Hikari Reiki]
# 420    120259084299                                       [I_am_Dhidee😍❤️✨]
# 421    120259084300                                    [Ipomo 🌙 | ENVtuber]
# 422    120259084301                                          [Jason Taylor]
# 423    120259084302                                  [Jean-Yves Gonin, CPA]
# 424    120259084303                                      [John Pennington💙]
# 425    120259084304                                                [Maryum]
# 426    120259084305                                        [Mewni Universe]
# 427    120259084306                                       [Michelle Lockey]
# 428    120259084307       [NFT HUNTER 👀| 'COINBASE NFTS AND MORE' in BIO ❗]
# 429    120259084308                                        [Patrick Boland]
# 430    120259084309                                       [Shashank Nirmal]
# 431    120259084310                                      [Stephanie Mensah]
# 432    120259084311                                        [TheHighIndian💙]
# 433    120259084312                                             [abW◡̈🐧ia🎢]
# 434    120259084313                                              [brohalfa]
# 435    120259084314                                [▀▄▀▄▀▄ 𝒜𝓃𝒸𝑒𝓈𝓉𝑜𝓇 ▄▀▄▀▄▀]
# 436    120259084315                                                 [👣 👀 ❤]
# 437    120259084316                            [📣Rewatching OP Ep 816/???⚓]
# 438    128849018880                                                 [ANWAR]
# 439    128849018881                                          [April Spivey]
# 440    128849018882                           [BUY MONONOKEINU/DIGINU NOW📈]
# 441    128849018883                                 [Big Picture Film Club]
# 442    128849018884                                        [Call_me_lekito]
# 443    128849018885                                     [Camilla Gleditsch]
# 444    128849018886                                    [Christopher Reinas]
# 445    128849018887                                               [Emocats]
# 446    128849018888                                           [Esha Kakkar]
# 447    128849018889                                       [Flo_Nightingail]
# 448    128849018890                                           [Frances Kim]
# 449    128849018891                                       [Jonathan McRae™]
# 450    128849018892                                              [MARKHOR🚀]
# 451    128849018893                                  [Nay (Naoko Mullally)]
# 452    128849018894                                        [NotGeorgeLucas]
# 453    128849018895                                      [Parrot Analytics]
# 454    128849018896                                            [Phill Gray]
# 455    128849018897                                       [QT Gaming Playz]
# 456    128849018898                                      [Rachel Stevenson]
# 457    128849018899                                           [Ritzi Giron]
# 458    128849018900                                        [Scott Elchison]
# 459    128849018901                                                [Slator]
# 460    128849018902                                     [Srinivasan Sankar]
# 461    128849018903                                        [TheHattedGamer]
# 462    128849018904                                   [WeGetDubbed Podcast]
# 463    128849018905                                          [Zeina Haddad]
# 464    128849018906                                       [a” in s4 denial]
# 465    128849018907                                           [beingKonGar]
# 466    128849018908                                                 [jason]
# 467    128849018909                                          [luckydrizzy🍀]
# 468    128849018910                                         [🌈 d a r c y 🍥]
# 469    128849018911                                 [🦖🦕mr boy (Juliette)🦕🦖]
# 470    137438953472                                           [#LordHanson]
# 471    137438953473                                [& TAKI DEBUT & | Joyce]
# 472    137438953474                                          [Adam Gaither]
# 473    137438953475                                   [Alonso M. Zamarripa]
# 474    137438953476                                    [BamBamBitcoin #321]
# 475    137438953477                                        [Barry Naylor ن]
# 476    137438953478                      [BigDadT ( USE STARCODE: CLOVER )]
# 477    137438953479                                         [Blaine Bishop]
# 478    137438953480                                        [Bollywood News]
# 479    137438953481                 [Citizenj17 { I’m feeling the Spirit }]
# 480    137438953482                                           [David Ernst]
# 481    137438953483                                             [Dion Lynk]
# 482    137438953484                                                 [Fahad]
# 483    137438953485                                          [Gawn Weelyan]
# 484    137438953486                                        [Guardian_Elite]
# 485    137438953487                                                  [JM77]
# 486    137438953488                                       [JamshaidSomra🇵🇰]
# 487    137438953489                                            [Juan Pilar]
# 488    137438953490                                          [K-FROG Radio]
# 489    137438953491                                            [Koki Najma]
# 490    137438953492                                            [Lolitsalan]
# 491    137438953493                                          [Nikki Jacobs]
# 492    137438953494                                           [Nina Burman]
# 493    137438953495                                        [Perfect Soccer]
# 494    137438953496                                   [SQUID GAME PROTOCOL]
# 495    137438953497                                        [Samuel Caceres]
# 496    137438953498                                      [Stefano Di Lollo]
# 497    137438953499                                       [Stuart 💙🏴󠁧󠁢󠁳󠁣󠁴󠁿]
# 498    137438953500                                           [Sylva Senat]
# 499    137438953501                                           [Vancity NFT]
# 500    137438953502                                     [back to work ?? 🕎]
# 501    137438953503                                                   [yan]
# 502    137438953504                                      [𝕮𝖔𝖓𝖓𝖔𝖗  @🏠🇬🇧👻🎃💀]
# 503    137438953505                                        [🅳🆁 🄱. 🅅🄸🄻🄻🅴🅶🅰🆂]
# 504    146028888064                                               [Abhinav]
# 505    146028888065                                                  [Ac17]
# 506    146028888066                                     [Ademir Villacorta]
# 507    146028888067                                        [BloombergQuint]
# 508    146028888068                                      [Buywell DayToday]
# 509    146028888069                                           [Chetan Kale]
# 510    146028888070                                                 [Clare]
# 511    146028888071                                         [Count GAshula]
# 512    146028888072                                      [Gaming Architect]
# 513    146028888073                                          [Gaming Grace]
# 514    146028888074                                            [Ingrid 🎶🎙😸]
# 515    146028888075                           [Joseph (jos3ph.eth) Pallant]
# 516    146028888076                                        [Kreem Franklin]
# 517    146028888077                                           [Layar Hijau]
# 518    146028888078                           [Leonel El Rojo 🏳️‍🌈 🇨🇱 ❤️🇵🇸]
# 519    146028888079                                              [Limandao]
# 520    146028888080                                                  [Maël]
# 521    146028888081                                             [Md Afridi]
# 522    146028888082                                [Mortal Machine Gallery]
# 523    146028888083                                              [PNW.HODL]
# 524    146028888084                                         [ProBit Global]
# 525    146028888085                                    [Produced by Famous]
# 526    146028888086                                     [Random Encounters]
# 527    146028888087                                            [Ryan Smith]
# 528    146028888088                      [SL ⁷ 🧈 PLS GET VACCINATED!!! 🖤💜💙]
# 529    146028888089                                          [SarahGen | ☕]
# 530    146028888090                                                [Sarie🍀]
# 531    146028888091                           [Spotted Lanternfly Smoosher]
# 532    146028888092                                             [Tim Quint]
# 533    146028888093                                            [Usha Sapra]
# 534    146028888094                                       [VUVU MAVUTHELA♠]
# 535    146028888095                                       [Venny Sintya II]
# 536    146028888096                                 [Virgin Radio Edmonton]
# 537    146028888097                                               [Zค𝔦ภ 🇵🇰]
# 538    146028888098                                         [dermeckerling]
# 539    146028888099                                         [husen 🏴󠁧󠁢󠁥󠁮󠁧󠁿]
# 540    146028888100                                       [iTzBLACKEY🙎🏽‍♂️]
# 541    146028888101                                             [solethada]
# 542    146028888102                                                    [⛧︎]
# 543    146028888103                                            [メタルヒーロージョン]
# 544    146028888104                                [👑🐯WinTae~Bear⁷(💜T⁷)!🐥🙌]
# 545    154618822656                                 [A.S.A.P. Mo Bippy 251]
# 546    154618822657                                  [BBC Radio Manchester]
# 547    154618822658                      [Bama Yankee.... LEVEL 4 WIZARD 🍅]
# 548    154618822659                                             [ButMadNNW]
# 549    154618822660                                 [Changer : Dear Yani 💓]
# 550    154618822661                               [Dave Linden Voice Actor]
# 551    154618822662                                     [Feodor Chin 💙🇺🇸❄️]
# 552    154618822663                                          [GalaxySystem]
# 553    154618822664                                         [Half Engineer]
# 554    154618822665                                       [Jovon Valentine]
# 555    154618822666                                     [LucasGitanoFamily]
# 556    154618822667                                    [MARKETING MAGAZINE]
# 557    154618822668                                      [Mala Wang-Naveen]
# 558    154618822669                                               [Manar👑.]
# 559    154618822670                                      [Mosharof Hossain]
# 560    154618822671                                           [Nitin Verma]
# 561    154618822672                                 [OG Otter Organization]
# 562    154618822673                                             [ROHIT SAH]
# 563    154618822674                                    [Rob in Winecountry]
# 564    154618822675                                          [ScoopingNews]
# 565    154618822676                                            [Stevieness]
# 566    154618822677                                      [Tellychakkar.com]
# 567    154618822678                                            [TheBrew.ae]
# 568    154618822679                                   [Tim French (he/him)]
# 569    154618822680                                                 [Tom 🌎]
# 570    154618822681                                       [Tony Milanowski]
# 571    154618822682                                       [Trevor Campbell]
# 572    154618822683                                   [Unique NFT Airdrops]
# 573    154618822684                                        [aka Matt Price]
# 574    154618822685                                        [beckysayswords]
# 575    154618822686                                            [theajsound]
# 576    154618822687                                          [🅰🅽🆃🅸-🆃🅰🅻🅸🅱🅰🅽]
# 577    154618822688                                             [🌷Leecock🌷]
# 578    154618822689                               [💉DFBR: 13,113-4,892-440]
# 579    163208757248                                                  [3NoK]
# 580    163208757249                                         [Aditya Basrur]
# 581    163208757250                                           [Airdrop Max]
# 582    163208757251                                        [Andrew Lifford]
# 583    163208757252                                  [Billy May | Trashy 🦝]
# 584    163208757253                                                  [Ch@d]
# 585    163208757254                                              [Colin Ⓜ️]
# 586    163208757255                                       [Culture Crave 🍿]
# 587    163208757256                                            [DJ Schemes]
# 588    163208757257                                       [Dr. Daniel, PhD]
# 589    163208757258                                         [Flip Benjamin]
# 590    163208757259                                                 [GROND]
# 591    163208757260                                      [Guardian Life NG]
# 592    163208757261                                              [Hrisoula]
# 593    163208757262                                   [Idris Demirsoy, PhD]
# 594    163208757263                                            [Iris 8v8 🌖]
# 595    163208757264                                                 [Jason]
# 596    163208757265                                   [Johnny Gem Hunter 💎]
# 597    163208757266                                       [Md Monirujjaman]
# 598    163208757267                                               [Mehil❤️]
# 599    163208757268                                            [Nadim khan]
# 600    163208757269                                      [Naima Roble 🇸🇴🇬🇧]
# 601    163208757270                                  [Ottawa Life Magazine]
# 602    163208757271                                      [Pros per Isidore]
# 603    163208757272                                          [Ryan Francis]
# 604    163208757273                                          [Simon Abbate]
# 605    163208757274                                           [Spoofs 🤍🎩☁️]
# 606    163208757275                  [Stay Home 🏡 Stay Safe ♥️ Wear Mask 😷]
# 607    163208757276                                         [The Geek Show]
# 608    163208757277                                                [Verity]
# 609    163208757278                                   [leagueofadvertising]
# 610    163208757279                                        [mentalmarketer]
# 611    163208757280                                          [richrichmond]
# 612    163208757281                                                [serdar]
# 613    163208757282                                            [tramøntø 💔]
# 614    163208757283                                       [wunderingspirit]
# 615    163208757284                                            [รгเ[ஸ்ரீ]™]
# 616    163208757285                                            [✭ Fabian ✭]
# 617    171798691840                                       [@RatulHowlader6]
# 618    171798691841                    [ASLAN (💎The Wolf of Bread Street💎)]
# 619    171798691842                                               [AVCesar]
# 620    171798691843                                       [Aaron Challoner]
# 621    171798691844                                            [Akash Rout]
# 622    171798691845                                             [Aldobear7]
# 623    171798691846                                    [Anik chowdhury ove]
# 624    171798691847                                        [Anthony Santos]
# 625    171798691848                                     [Ashley Batzer, JD]
# 626    171798691849                                    [BLACK LIVES MATTER]
# 627    171798691850                                            [CryptoGirl]
# 628    171798691851                                          [C✨Wanderlust]
# 629    171798691852                                                  [Doug]
# ...
# 5862  1657857376256                                 [AAAHHHshley Casperite]
# 5863  1657857376257                                            [ADA Ninjaz]
# 5864  1657857376258                                           [Amit sharma]
# 5865  1657857376259                                           [Areum Jeong]
# 5866  1657857376260                    [Big Gary Slaughter, Comic Shop ACE]
# 5867  1657857376261                                      [BlocWars Project]
# 5868  1657857376262                                         [Brett Megarry]
# 5869  1657857376263                                          [Charles Muia]
# 5870  1657857376264                                          [Chris Hendel]
# 5871  1657857376265                               [DHL eCommerce Solutions]
# 5872  1657857376266                                          [DiamantenCop]
# 5873  1657857376267                                      [Do you do drugs?]
# 5874  1657857376268                                       [Donny permana 🎏]
# 5875  1657857376269                                      [Dr. Laura Duggan]
# 5876  1657857376270                                      [East Coast Radio]
# 5877  1657857376271                                          [Gaymers iNC.]
# 5878  1657857376272                                         [JBtradz.eth 👽]
# 5879  1657857376273                                      [Just Becca 🌈🎃👻💀🎃]
# 5880  1657857376274                                               [Kirstie]
# 5881  1657857376275                                                 [Lapis]
# 5882  1657857376276                                            [Laura Duff]
# 5883  1657857376277                                   [Lauren Conte/Mathis]
# 5884  1657857376278                                    [Miss Artie Craftie]
# 5885  1657857376279                                                    [Mo]
# 5886  1657857376280                                                 [Mouli]
# 5887  1657857376281                                   [Nuvaid Vaidyaravida]
# 5888  1657857376282                                           [QurlyMa 🎮🎤🎶]
# 5889  1657857376283                                        [RK'S ART WORLD]
# 5890  1657857376284                             [Stop the madness, please!]
# 5891  1657857376285                               [Telfordtheultimateguide]
# 5892  1657857376286                                         [Tom Mitcheson]
# 5893  1657857376287                                        [Tracey Symonds]
# 5894  1657857376288                                    [Trinisha Mukherjee]
# 5895  1657857376289                                    [Vacina já!✊🏿✊🏾✊🏽✌🏾]
# 5896  1657857376290                                       [Vahab Ahmadvand]
# 5897  1657857376291                                             [YuChuiYee]
# 5898  1657857376292                                         [Zaigoinfotech]
# 5899  1657857376293                                [ad | wi ha joon simper]
# 5900  1657857376294                                        [gabriellaQATAR]
# 5901  1657857376295                                                 [ʟᴀᴜ 🪐]
# 5902  1657857376296                                            [รσℓ∂α∂σ 23]
# 5903  1657857376297                                           [🌟DeMoment 🌟]
# 5904  1666447310848                                              [Big 98.5]
# 5905  1666447310849                                 [CHANGEJLSMEETANDGREET]
# 5906  1666447310850                                           [Corey Floyd]
# 5907  1666447310851                                                  [Devi]
# 5908  1666447310852                                    [EMGG | NeighborGMR]
# 5909  1666447310853                                            [Emon Ahmed]
# 5910  1666447310854                                     [Fun Sugar Cookies]
# 5911  1666447310855                                              [Gavin S.]
# 5912  1666447310856                                           [HEAVEN RAIN]
# 5913  1666447310857                                             [HXE (Hue)]
# 5914  1666447310858                                            [Holly. 🖤☀️]
# 5915  1666447310859                                        [JJ Froud Draws]
# 5916  1666447310860                                     [Josiah Mahachi 🇿🇼]
# 5917  1666447310861                                              [JustHere]
# 5918  1666447310862                                          [Lokman Hakim]
# 5919  1666447310863      [Marty Kyogo 🇯🇵 - Hostage of an Involuntary Union]
# 5920  1666447310864                        [Pecaminosa - A Pixel Noir Game]
# 5921  1666447310865                [PingMeansPeace🌏 #WarsAreProductsOfLies]
# 5922  1666447310866                                               [RGCnews]
# 5923  1666447310867                                                [Rashee]
# 5924  1666447310868                                                 [Swell]
# 5925  1666447310869                                            [Talking TV]
# 5926  1666447310870                                          [Texas Signal]
# 5927  1666447310871                              [Those SKYRAILS NEWS 🚫🚝🏚🚫]
# 5928  1666447310872                                     [ThunderPixelGames]
# 5929  1666447310873                                         [Timothy Keith]
# 5930  1666447310874                                                [Vane⁷៹]
# 5931  1666447310875                                          [iLikeGreen 🌍]
# 5932  1666447310876                                            [tarun 👉🏻👈🏻]
# 5933  1666447310877                                     [✨SparkleTheWorld✨]
# 5934  1666447310878                                        [🕯️ 🍂 Turox 🎃 🦇]
# 5935  1675037245440                                            [Abdul Alim]
# 5936  1675037245441                                      [Ahmet Ender Ataç]
# 5937  1675037245442                                       [Aisling Schmidt]
# 5938  1675037245443                                           [David K. Li]
# 5939  1675037245444                                          [Dhan Bahadur]
# 5940  1675037245445                                 [Dorothy Shaine Samson]
# 5941  1675037245446                [Dramas Over Flowers: A K-drama Podcast]
# 5942  1675037245447                                                    [Ed]
# 5943  1675037245448                [FLC ✊🏿 #UnlearnHate #EveryChildMatters]
# 5944  1675037245449                                            [Froggy 101]
# 5945  1675037245450                                       [James Armstrong]
# 5946  1675037245451                                             [JeyaKumar]
# 5947  1675037245452                                            [Jim McGill]
# 5948  1675037245453                                                [Leslie]
# 5949  1675037245454                                                   [MAY]
# 5950  1675037245455                                 [Md Samioul Islam Sani]
# 5951  1675037245456                                      [Micheaux Spencer]
# 5952  1675037245457                                          [Murtz Jaffer]
# 5953  1675037245458                                           [Nirav Patel]
# 5954  1675037245459                                            [NotACritic]
# 5955  1675037245460                                          [Péter Kapusi]
# 5956  1675037245461                                        [Q101 Hit Music]
# 5957  1675037245462                                        [Rodney Jeninga]
# 5958  1675037245463                                         [Salavat Fidai]
# 5959  1675037245464                                              [Sang Lam]
# 5960  1675037245465                                              [Savvy_gr]
# 5961  1675037245466                                         [Shyama Dash 📸]
# 5962  1675037245467                             [The Uncontrollable Hazard]
# 5963  1675037245468                                   [WhitleyLodgeSnooker]
# 5964  1675037245469                                               [heney 🦇]
# 5965  1675037245470                                          [johnmcginley]
# 5966  1675037245471                                        [officialellenk]
# 5967  1675037245472                                 [translationandsocials]
# 5968  1675037245473                        [🆘🍑Puddn♀️Haid🍑🆘 📱202.224.3121📱]
# 5969  1683627180032                                                   [Ali]
# 5970  1683627180033                                          [Ali Tahmasbi]
# 5971  1683627180034                                       [Bespoke Careers]
# 5972  1683627180035                                   [Carrie Thomas 🎃🧛‍♀️]
# 5973  1683627180036                                                [Carter]
# 5974  1683627180037                                          [Cicero Silva]
# 5975  1683627180038                                             [Dapsy🇳🇬🇨🇦]
# 5976  1683627180039                                          [Faisal Bakri]
# 5977  1683627180040                                           [Fred Anyona]
# 5978  1683627180041                        [Jade 🎃 Trick-or-Treat 👻 MD PhD]
# 5979  1683627180042                                      [Kiel Robinson 🇬🇧]
# 5980  1683627180043                                               [Kyle N.]
# 5981  1683627180044                                                 [Ludus]
# 5982  1683627180045                               [M i s s W a r t a a l ©]
# 5983  1683627180046                                          [Md Liton Mia]
# 5984  1683627180047                                          [NEON_DEMON 😈]
# 5985  1683627180048                                               [Nai Mei]
# 5986  1683627180049                                      [Natasa Lazarevic]
# 5987  1683627180050                                               [OCshree]
# 5988  1683627180051                                        [Portal of Toys]
# 5989  1683627180052                                          [Randem Gamor]
# 5990  1683627180053                                   [Randolph Wade Elder]
# 5991  1683627180054                                         [Roberto Swazo]
# 5992  1683627180055                                      [SACHIN K CHITALE]
# 5993  1683627180056                                               [SHIVASK]
# 5994  1683627180057                                         [SinCityFreaks]
# 5995  1683627180058                                          [Somaya Reece]
# 5996  1683627180059                                          [eric raddatz]
# 5997  1683627180060                                         [🐾 shai ; ʚ◡̈ɞ]
# 5998  1692217114624                                         [Abid Hassan 🎏]
# 5999  1692217114625                                              [Atif Ali]
# 6000  1692217114626                                      [Brian T. Jackett]
# 6001  1692217114627                                              [Cepkolik]
# 6002  1692217114628                                         [Damini Chopra]
# 6003  1692217114629                             [Dr Margarita Peredaryenko]
# 6004  1692217114630                                             [IDisagree]
# 6005  1692217114631                                           [John Gateru]
# 6006  1692217114632                                    [Keiti U 🌟 ENVTuber]
# 6007  1692217114633                                             [LUXURYart]
# 6008  1692217114634                                       [Larry Dougherty]
# 6009  1692217114635                                            [MD.HUMAYUN]
# 6010  1692217114636                                                [Mark V]
# 6011  1692217114637                                    [Mr Nifedipine ♚ 🇳🇬]
# 6012  1692217114638                                             [NEW🗽102.7]
# 6013  1692217114639                            [PaTresha 🎃👻🌊💙PresidentJoe💙]
# 6014  1692217114640                                            [Sale X Low]
# 6015  1692217114641                                       [SquidGodFinance]
# 6016  1692217114642                                   [Stavroula Sokoli 🗺️]
# 6017  1692217114643                                         [Steve Leach 🛒]
# 6018  1692217114644                                          [The Squids 🐙]
# 6019  1692217114645                                          [Vignesh HaRi]
# 6020  1692217114646                                        [Wendy Shepherd]
# 6021  1692217114647                                               [felidae]
# 6022  1692217114648                                            [luahuynh94]
# 6023  1692217114649                                              [lɑnᧉ | ★]
# 6024  1692217114650                                 [🍷🚀⚗️🌘🦕S K MOORE👽🤖🪐 🔭π]
# 6025  1700807049216                [@ÅnDr.ewJ.Cr@wf0rD., Esq.🤔😟😢😥😰☔😱😭💧🌊😎😎😎]
# 6026  1700807049217                                       [Austin Docherty]
# 6027  1700807049218                                            [Chrissy Ha]
# 6028  1700807049219                                    [Duartech Solutions]
# 6029  1700807049220          [Faeries and Ents - Comics, books, and stuff!]
# 6030  1700807049221                                           [Hal Rudnick]
# 6031  1700807049222                                           [Igo saputra]
# 6032  1700807049223                [Interstellar Credit Systems - ICS Labs]
# 6033  1700807049224                                          [Jason Cosper]
# 6034  1700807049225                    [Long Ween Club | MINTING OCT 19th!]
# 6035  1700807049226                                         [Maggie Alonzo]
# 6036  1700807049227                                                 [Mairo]
# 6037  1700807049228                                           [MochaCytoma]
# 6038  1700807049229                                           [Molly Heart]
# 6039  1700807049230                                                [News24]
# 6040  1700807049231                                            [Ojo Diwoco]
# 6041  1700807049232                               [Passmore Coast To Coast]
# 6042  1700807049233                                         [Patrick Leger]
# 6043  1700807049234                                             [THE SHACK]
# 6044  1700807049235                                         [Todd Spangler]
# 6045  1700807049236                                             [Veronique]
# 6046  1700807049237                                           [Vortex Mood]
# 6047  1700807049238         [˗ˏˋuıʍʇʎdəəɹɔˎˊ˗ 👑 King of the Reply Guys 🗨️🐦]
# 6048  1700807049239                                            [ᴀᴅᴀᴍ ʙᴏʏᴇs]
# 6049  1700807049240                                       [🎃JustDavidEGS ]
# 6050  1700807049241                                         [💙тω∂ιятуgιяℓѕ]
# 6051  1709396983808                                [African Glitz Magazine]
# 6052  1709396983809                                                  [Cabi]
# 6053  1709396983810                                               [Dan_G4L]
# 6054  1709396983811                                         [Eldritch Lord]
# 6055  1709396983812                                        [Evobots Colony]
# 6056  1709396983813                                               [GloMula]
# 6057  1709396983814                                           [Juan Markos]
# 6058  1709396983815                                             [Lumo_Chen]
# 6059  1709396983816                                                  [MATU]
# 6060  1709396983817                                        [Meli (she/her)]
# 6061  1709396983818                                      [Mercelyn ⁷ ⟭⟬ 🧈💛]
# 6062  1709396983819                                       [PBG D-201/407 ♡]
# 6063  1709396983820                                                   [PUD]
# 6064  1709396983821                                         [Ranjeet Patil]
# 6065  1709396983822                                          [Richard Luck]
# 6066  1709396983823                                                   [Taz]
# 6067  1709396983824                    [US101 Chattanooga’s #1 for Country]
# 6068  1709396983825                                             [asif khan]
# 6069  1709396983826                                            [dreadknots]
# 6070  1709396983827                                         [i am reusable]
# 6071  1709396983828                                        [𝓞𝓵𝓲𝓼𝓮 𝓐𝓭𝓲𝓰𝔀𝓮 ✰]

# %% [markdown]
# <a id='3.4'></a>
# **4. Conversation: Which are the top 5 most important accounts in the SquidGame conversation?**

# %%
tweets_rank = tweets_graph.pageRank(resetProbability=0.15, maxIter=10)

# %%
tweets_rank.vertices.orderBy(desc("pagerank")).limit(5).toPandas()
# Out:
#                 id   pagerank
# 0  SquidGodFinance  23.628059
# 1      ACSupremacy   6.577052
# 2        toysrevil   6.577052
# 3       cainecapri   6.577052
# 4     laflarenyinc   6.577052

# %%
tweets_rank.edges.limit(5).toPandas()
# Out:
#                                           src              dst  occurrences  \
# 0                               Nadim Hossain  SquidGodFinance            1
# 1                                 Ahli Syurga  SquidGodFinance            1
# 2                           MD MOMINUL ISLAM🎏  SquidGodFinance            1
# 3                                   John Doge      PunkPikazzo            1
# 4  ❤⃝sᷤhͪaⷶkᷜiͥlᷝ ❤⃝⃝aⷶhͪmͫeͤdͩ.near 🎣🎏 #KOII  SquidGodFinance            1
#
#    weight
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %% [markdown]
# <a id='3.5'></a>
# **5. Conversation: Which are the top 5 accounts that mentioned other accounts the most in the SquidGame conversation?**

# %%
tweets_graph.outDegrees.orderBy(col("outDegree").desc()).limit(5).toPandas()
# Out:
#                  id  outDegree
# 0         John Doge        207
# 1   michael jackson         68
# 2        marziolowe         62
# 3  Crypto Mushroomz         55
# 4        WINK_PANDA         50

# %% [markdown]
# <a id='3.6'></a>
# **6. Conversation: Which are the top 5 accounts that were mentioned the most in the SquidGame conversation?**

# %%
tweets_graph.inDegrees.orderBy(col("inDegree").desc()).limit(5).toPandas()
# Out:
#               id  inDegree
# 0        netflix       872
# 1  GoGoSquidGame       196
# 2        YouTube       122
# 3   NetflixIndia        93
# 4  SunflameIndia        83

# %% [markdown]
# <a id='4'></a>
# # 4. Export graph data
# <p>If we need to export the data for graphing purposes  we can use the datasource API to create the files. These files can be used with tools like <a href='https://gephi.org/'>Gephi</a> to create graph visualizations.

# %%
tweets_vertices.coalesce(1).write.mode("overwrite").option("header","true").csv("hdfs://localhost:9000/export/SquidGame_tweets_vertices/")
tweets_edges.coalesce(1).withColumnRenamed("src","Source")\
                   .withColumnRenamed("dst","Destination")\
                   .write.mode("overwrite").option("header","true").csv("hdfs://localhost:9000/export/SquidGame_tweets_edges/")

# %% [markdown]
# <a id='5'></a>
# # 5. Please, terminate the tools used
# <p>Once we have completed this notebook we can stop all the services.

# %% [markdown]
# <a id='5.1'></a>
# ### 5.1 Stop Hadoop application
# <ul>
#     <li><p><b>Stops the Hadoop service by opening a terminal and execute:</b>:
#         <br/><em>\$ hadoop-stop.sh</p></em><br/></li>
